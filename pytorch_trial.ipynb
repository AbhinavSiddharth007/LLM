# %%
import torch
import torch.nn as nn
from torch import *
import random

# %%
def Game():
    try:
        x  = int(input("Enter a number"))
        list_of_countries = ["India", "Spain", "Brazil","Switzerland"]
        

    except ValueError:
         print("re try")

# %%
# tensor1 = torch.tensor([1,2,3])
# tensor2 = torch.tensor([4,5,6])

# stacked_tensor = tensor.stacked_tensor(tensor1,tensor2)

# print(stacked_tensor)
